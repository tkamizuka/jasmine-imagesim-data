# %%
import numpy as np
import matplotlib.pylab as plt

# %%
data = []
data.append(np.loadtxt('02_results_ctl0_det00_tel00/data_accuracy.dat'))
data.append(np.loadtxt('02_results_ctl1_det00_tel00/data_accuracy.dat'))
data = np.array(data)

# %%
plt.errorbar(data[0,:,0], data[0,:,1], yerr=data[0,:,2], linestyle='None', label='RealPSF')
plt.errorbar(data[1,:,0], data[1,:,1], yerr=data[1,:,2], linestyle='None', label='RealPSF+GaussACE')
plt.yscale('log')
plt.legend()
plt.xlabel('Object magnitude (mag)')
plt.ylabel('Position accuracy (px)')
plt.show()
