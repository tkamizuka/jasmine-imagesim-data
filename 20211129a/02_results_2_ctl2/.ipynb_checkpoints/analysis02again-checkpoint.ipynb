# %% [markdown]
# # Astrometric analysis with ePSF

# %% [markdown]
# In this directory, the data calculated with ctl2.json are examined.
#
# Conditions: Real PSF, No Flat, No ACE, No WFE, w/o detector offset.

# %% [markdown]
# ## Importing some modules

# %%
import copy, warnings
import numpy as np
import matplotlib.pyplot as plt
import astropy.io.fits as pf
from astropy.modeling import models, fitting
from astropy.nddata import NDData
from astropy.stats import sigma_clipped_stats
from astropy.table import Table
from astropy.visualization import simple_norm
from photutils.background import MMMBackground
from photutils.detection import find_peaks
from photutils.psf import EPSFBuilder, extract_stars

# %% [markdown]
# ## Defining a function

# %%
def func(filename, sp_filename, mag, n_oversample, n_maxiter):
    '''
    filename: Name of the input FITS file.
    sp_filename: Name of the input star-plate file.
    '''
    
    mask_size = 25   # Edge mask size.
    ext_size  = 9    # Size of extraction window.
#    n_oversample = 4 # Number of oversampling for ePSF.
#    n_maxiter    = 3 # Max. number of iteration for making ePSF.
    threshold = 3000.*10.**((mag-12.0)/(-2.5))
#    print("Analyzing {}...".format(filename))
    
    # Loading image.
    hdu = pf.open(filename)[0]
    data = hdu.data.astype(np.float32)
    norm = simple_norm(data, 'sqrt', percent=99.)
#    plt.imshow(data, norm=norm, origin='lower', cmap='viridis')
#    plt.xlabel('X (px)')
#    plt.ylabel('Y (px)')
#    plt.show()
    
    # Finding peaks.
    peaks_tbl = find_peaks(data, threshold=threshold)
    peaks_tbl['peak_value'].info.format = '%.8g'  # for consistent table output
#    print(peaks_tbl)
    
    # Removing detections near edge.
    hsize = (mask_size - 1) / 2
    x = peaks_tbl['x_peak'] 
    y = peaks_tbl['y_peak'] 
    mask = ((x > hsize) & (x < (data.shape[1] -1 - hsize)) &
            (y > hsize) & (y < (data.shape[0] -1 - hsize)))
    stars_tbl = Table()
    stars_tbl['x'] = x[mask]
    stars_tbl['y'] = y[mask]
#    print(stars_tbl)
    
    # Subtracting background.
    mean_val, median_val, std_val = sigma_clipped_stats(data, sigma=2.)  
    image = copy.deepcopy(data)
    data -= mean_val
#    plt.imshow(data, norm=norm, origin='lower', cmap='viridis')
#    plt.xlabel('X (px)')
#    plt.ylabel('Y (px)')

    # Extracting stellar images.
    nddata = NDData(data=data)
#    print(nddata.data.shape)
    stars = extract_stars(nddata, stars_tbl, size=ext_size)
#    nrows = 10
#    ncols = 10
#    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20, 20), squeeze=True)
#    ax = ax.ravel()
#    for i in range(nrows*ncols):
#        norm = simple_norm(stars[i], 'log', percent=99.)
#        ax[i].imshow(stars[i], norm=norm, origin='lower', cmap='viridis')
#    plt.show()
        
    # Making ePSF.
    epsf_builder = EPSFBuilder(oversampling=n_oversample,
                               maxiters=n_maxiter, progress_bar=True)
    epsf, fitted_stars = epsf_builder(stars)
    norm = simple_norm(epsf.data, 'log', percent=99.)
#    plt.imshow(epsf.data, norm=norm, origin='lower', cmap='viridis')
#    plt.xlabel('X (oversampled pix)')
#    plt.ylabel('Y (oversampled pix)')
#    plt.colorbar()
#    plt.show()

    # Loading stellar-plate data.
    original = np.loadtxt(sp_filename,skiprows=1,delimiter=",")
    
    # Cross-checking the data.
    xc_array = []
    for o in original:
        diff = fitted_stars.center_flat-np.array([o[2],o[3]])
        p = np.where(diff[:,0]**2.+diff[:,1]**2.<10.**2.)
        if np.size(p) == 1:
            xc_array.append([o[2], o[3],
                             fitted_stars.center_flat[p[0][0]][0],
                             fitted_stars.center_flat[p[0][0]][1]])
    xc_array = np.array(xc_array)
#    print(xc_array)
    
    # Making dx/dy data.
    dx = xc_array[:,2] - xc_array[:,0]
    dy = xc_array[:,3] - xc_array[:,1]
    dx = dx - np.mean(dx)
    dy = dy - np.mean(dy)
#    plt.scatter(dx, dy)
#    plt.xlabel('$\Delta$x (px; w/o global offset)')
#    plt.ylabel('$\Delta$y (px; w/o global offset)')
#    plt.show()
    
#    plt.axes().set_aspect('equal')
#    plt.quiver(xc_array[:,2], xc_array[:,3], dx, dy,
#               angles='xy', scale_units='xy', scale=0.0003)
#    plt.xlabel('X (px)')
#    plt.ylabel('Y (px)')
#    plt.xlim([0, 1920])
#    plt.ylim([0, 1920])
#    plt.show()
    
    # Calculating stddev.
#    print("STDDEV DX: {} px".format(np.std(dx)))
#    print("STDDEV DY: {} px".format(np.std(dy)))
    stddx = np.std(dx)
    stddy = np.std(dy)
    stddr = np.std(np.sqrt(dx*dx+dy*dy))
    return stddx, stddy, stddr

# %%
mags = np.arange(12.0,15.0,0.5)

print("oversample 4...")
sra=[]
for mag in mags:
    tmp = []
    for i in range(0,11):
        sx, sy, sr = func("image.{:4.1f}.{:02d}.fits".format(mag,i),
                          "../01_params/spcsv_20_1920_10_20_12.0.csv", mag, 4, 10)
        tmp.append(sr)
    sra.append(tmp)
sra = np.array(sra)

srs = []
for i in range(6):
    print("Accuracy at {:4.1f} mag: {:7.5f} p/m {:7.5f} px".format(mags[i], np.mean(sra[i]),
                                                np.std(sra[i],ddof=1)/np.sqrt(np.size(sra[i]))))
    srs.append([mags[i], np.mean(sra[i]), np.std(sra[i],ddof=1)/np.sqrt(np.size(sra[i]))])
#    plt.plot(sra[i],label='{:4.1f} mag'.format(mags[i]))
#plt.yscale('log')
#plt.show()
srs4 = np.array(srs)

print("oversample 8")
sra=[]
for mag in mags:
    tmp = []
    for i in range(0,11):
        sx, sy, sr = func("image.{:4.1f}.{:02d}.fits".format(mag,i),
                          "../01_params/spcsv_20_1920_10_20_12.0.csv", mag, 8, 10)
        tmp.append(sr)
    sra.append(tmp)
sra = np.array(sra)

srs = []
for i in range(6):
    print("Accuracy at {:4.1f} mag: {:7.5f} p/m {:7.5f} px".format(mags[i], np.mean(sra[i]),
                                                np.std(sra[i],ddof=1)/np.sqrt(np.size(sra[i]))))
    srs.append([mags[i], np.mean(sra[i]), np.std(sra[i],ddof=1)/np.sqrt(np.size(sra[i]))])
#    plt.plot(sra[i],label='{:4.1f} mag'.format(mags[i]))
#plt.yscale('log')
#plt.show()
srs8 = np.array(srs)


print("oversample 12")
sra=[]
for mag in mags:
    tmp = []
    for i in range(0,11):
        sx, sy, sr = func("image.{:4.1f}.{:02d}.fits".format(mag,i),
                          "../01_params/spcsv_20_1920_10_20_12.0.csv", mag, 12, 10)
        tmp.append(sr)
    sra.append(tmp)
sra = np.array(sra)

srs = []
for i in range(6):
    print("Accuracy at {:4.1f} mag: {:7.5f} p/m {:7.5f} px".format(mags[i], np.mean(sra[i]),
                                                np.std(sra[i],ddof=1)/np.sqrt(np.size(sra[i]))))
    srs.append([mags[i], np.mean(sra[i]), np.std(sra[i],ddof=1)/np.sqrt(np.size(sra[i]))])
#    plt.plot(sra[i],label='{:4.1f} mag'.format(mags[i]))
#plt.yscale('log')
#plt.show()
srs12 = np.array(srs)



print("oversample 16")
sra=[]
for mag in mags:
    tmp = []
    for i in range(0,11):
        sx, sy, sr = func("image.{:4.1f}.{:02d}.fits".format(mag,i),
                          "../01_params/spcsv_20_1920_10_20_12.0.csv", mag, 16, 10)
        tmp.append(sr)
    sra.append(tmp)
sra = np.array(sra)

srs = []
for i in range(6):
    print("Accuracy at {:4.1f} mag: {:7.5f} p/m {:7.5f} px".format(mags[i], np.mean(sra[i]),
                                                np.std(sra[i],ddof=1)/np.sqrt(np.size(sra[i]))))
    srs.append([mags[i], np.mean(sra[i]), np.std(sra[i],ddof=1)/np.sqrt(np.size(sra[i]))])
#    plt.plot(sra[i],label='{:4.1f} mag'.format(mags[i]))
#plt.yscale('log')
#plt.show()
srs16 = np.array(srs)
# Out:
# oversample 4...
# Accuracy at 12.0 mag: 0.00363 p/m 0.00003 px
# Accuracy at 12.5 mag: 0.00420 p/m 0.00005 px
# Accuracy at 13.0 mag: 0.00504 p/m 0.00004 px
# Accuracy at 13.5 mag: 0.00655 p/m 0.00015 px
# Accuracy at 14.0 mag: 0.00817 p/m 0.00012 px
# Accuracy at 14.5 mag: 0.01191 p/m 0.00028 px
# oversample 8
# Accuracy at 12.0 mag: 0.00684 p/m 0.00010 px
# Accuracy at 12.5 mag: 0.00758 p/m 0.00014 px
# Accuracy at 13.0 mag: 0.00801 p/m 0.00010 px
# Accuracy at 13.5 mag: 0.00957 p/m 0.00011 px
# Accuracy at 14.0 mag: 0.01159 p/m 0.00022 px
# Accuracy at 14.5 mag: 0.01512 p/m 0.00026 px
# oversample 12
# Accuracy at 12.0 mag: 0.00867 p/m 0.00010 px
# Accuracy at 12.5 mag: 0.00923 p/m 0.00011 px
# Accuracy at 13.0 mag: 0.01017 p/m 0.00015 px
# Accuracy at 13.5 mag: 0.01207 p/m 0.00031 px
# Accuracy at 14.0 mag: 0.01471 p/m 0.00027 px
# Accuracy at 14.5 mag: 0.01811 p/m 0.00026 px
# oversample 16
# Accuracy at 12.0 mag: 0.01045 p/m 0.00009 px
# Accuracy at 12.5 mag: 0.01064 p/m 0.00011 px
# Accuracy at 13.0 mag: 0.01160 p/m 0.00013 px
# Accuracy at 13.5 mag: 0.01277 p/m 0.00017 px
# Accuracy at 14.0 mag: 0.01573 p/m 0.00032 px
# Accuracy at 14.5 mag: 0.01923 p/m 0.00025 px

# %%
plt.figure(facecolor='white')
plt.errorbar(srs4[:,0], srs4[:,1], yerr=srs4[:,2], capsize=5, fmt='o', markersize=2, 
             ecolor='brown', markeredgecolor = "brown", color='w', label='Oversample 4')
plt.errorbar(srs8[:,0], srs8[:,1], yerr=srs8[:,2], capsize=5, fmt='o', markersize=2, 
             ecolor='orange', markeredgecolor = "orange", color='w', label='Oversample 8')
plt.errorbar(srs12[:,0], srs12[:,1], yerr=srs12[:,2], capsize=5, fmt='o', markersize=2, 
             ecolor='green', markeredgecolor = "green", color='w', label='Oversample 12')
plt.errorbar(srs16[:,0], srs16[:,1], yerr=srs16[:,2], capsize=5, fmt='o', markersize=2, 
             ecolor='blue', markeredgecolor = "blue", color='w', label='Oversample 16')
plt.yscale('log')
plt.xlabel('Object magnitude (mag)')
plt.ylabel('Evaluated accuracy (px)')
plt.title('~400 Real-PSF objects')
plt.legend()
plt.show()
